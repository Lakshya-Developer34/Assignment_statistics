# %%
""" 
# Statistics Assignment

## Task 1: Daily app actions and type of data generated

| App action                           | Type of data | Example                     |
| ------------------------------------ | ------------ | --------------------------- |
| Liking an Instagram post             | Numerical    | Number of likes = 25        |
| Watching an Instagram reel category  | Categorical  | Comedy, Education, Travel   |
| Giving a restaurant rating on Zomato | Numerical    | Rating = 4.5                |
| Searching for food on Zomato         | Categorical  | Pizza, Burger, South Indian |
| Buying a product on Flipkart         | Numerical    | Price = ₹799                |

---

## Task 2: Classify the music app data

**Data:** ['Pop', 'Rock', 'Jazz', 'Hip-Hop', 'Pop', 'Rock', 'Jazz', 'Pop']

This is **categorical (nominal) data** because it contains names of music genres rather than numbers. The values are labels such as Pop and Rock, and they do not have any numerical meaning or order.

---

## Task 3: Statistics in an app feature

**Feature chosen:** Number of likes on an Instagram post.

Statistics can help Instagram identify which posts are most popular by calculating the average likes, growth rate of likes, and engagement patterns. This information can be used to show users more interesting content and improve their feed recommendations.

---

## Task 4: Statistical terms for a playlist recommendation feature

| Statistical term | Meaning                                          | One-line example                                                                    |
| ---------------- | ------------------------------------------------ | ----------------------------------------------------------------------------------- |
| **Mean**         | Average value                                    | A user listens to songs for an average of **30 minutes per day**.                   |
| **Mode**         | Most frequently occurring value                  | **Pop** is the genre listened to most often by the user.                            |
| **Variance**     | Measures how much values differ from the average | Listening time varies a lot between weekdays and weekends, so the variance is high. |

These statistics help the app understand user behavior and recommend songs that better match listening habits.

"""
